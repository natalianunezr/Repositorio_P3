# %% [markdown]
# ## Proyecto 3 - Modelización
#
# Desarrollado por David Gutiérrez & Natalia Núñez

# %% [markdown]
# ![Descripción de la imagen](RED_ICFES.png)

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import math
from pgmpy.models import BayesianModel
from pgmpy.models import BayesianNetwork
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator
from pgmpy.inference import VariableElimination
from sklearn.metrics import confusion_matrix
import numpy as np
import os
from pgmpy.sampling import BayesianModelSampling
from pgmpy.factors.discrete import TabularCPD
from sklearn.model_selection import train_test_split

# %%
# Crear un DataFrame de ejemplo
df = pd.DataFrame({'Municipio': ['Municipio A', 'Municipio B', 'Municipio A', 'Municipio C', 'Municipio B']})

# Obtener los números únicos para cada municipio
df['Municipio_Numero'] = pd.factorize(df['Municipio'])[0]

# Imprimir el DataFrame resultante
print(df)
# Out:
#      Municipio  Municipio_Numero
# 0  Municipio A                 0
# 1  Municipio B                 1
# 2  Municipio A                 0
# 3  Municipio C                 2
# 4  Municipio B                 1

# %%
# Leer el archivo CSV

df = pd.read_csv("datos_p3.csv")
print(df.columns)
print(df["FAMI_TIENEINTERNET"].describe())
print(df["FAMI_TIENEINTERNET"].unique())
# Out:
# Index(['PERIODO', 'COLE_AREA_UBICACION', 'COLE_BILINGUE',
#        'COLE_DEPTO_UBICACION', 'COLE_JORNADA', 'COLE_MCPIO_UBICACION',
#        'ESTU_GENERO', 'FAMI_EDUCACIONMADRE', 'FAMI_EDUCACIONPADRE',
#        'FAMI_ESTRATOVIVIENDA', 'FAMI_TIENEINTERNET', 'PUNT_GLOBAL'],
#       dtype='object')
# count     869322
# unique         2
# top           Si
# freq      541859
# Name: FAMI_TIENEINTERNET, dtype: object
# ['No' 'Si']

# %%
#Tenemos que discretizar periodo y puntaje global
#Discretizar cole area ubicacion
df["COLE_AREA_UBICACION_DISCRETO"] = df["COLE_AREA_UBICACION"]
df['COLE_AREA_UBICACION'] = pd.factorize(df['COLE_AREA_UBICACION_DISCRETO'])[0]

#Discretizar cole bilingue
df["COLE_BILINGUE_DISCRETO"] = df["COLE_BILINGUE"]
df['COLE_BILINGUE'] = pd.factorize(df['COLE_BILINGUE_DISCRETO'])[0]

#Discretizar COLE_DEPTO_UBICACION
df["COLE_DEPTO_UBICACION_DISCRETO"] = df["COLE_DEPTO_UBICACION"]
df['COLE_DEPTO_UBICACION'] = pd.factorize(df['COLE_DEPTO_UBICACION_DISCRETO'])[0]

#Discretizar COLE_JORNADA
df["COLE_JORNADA_DISCRETO"] = df["COLE_JORNADA"]
df['COLE_JORNADA'] = pd.factorize(df['COLE_JORNADA_DISCRETO'])[0]

#Discretizar COLE_MCPIO_UBICACION
df["COLE_MCPIO_UBICACION_DISCRETO"] = df["COLE_MCPIO_UBICACION"]
df['COLE_MCPIO_UBICACION'] = pd.factorize(df['COLE_MCPIO_UBICACION_DISCRETO'])[0]

#Discretizar FAMI_EDUCACIONMADRE
df["FAMI_EDUCACIONMADRE_DISCRETO"] = df["FAMI_EDUCACIONMADRE"]
df['FAMI_EDUCACIONMADRE'] = pd.factorize(df['FAMI_EDUCACIONMADRE_DISCRETO'])[0]

#Discretizar FAMI_EDUCACIONPADRE
df["FAMI_EDUCACIONPADRE_DISCRETO"] = df["FAMI_EDUCACIONPADRE"]
df['FAMI_EDUCACIONPADRE'] = pd.factorize(df['FAMI_EDUCACIONPADRE_DISCRETO'])[0]

#Discretizar FAMI_ESTRATOVIVIENDA
df["FAMI_ESTRATOVIVIENDA_DISCRETO"] = df["FAMI_ESTRATOVIVIENDA"]
df['FAMI_ESTRATOVIVIENDA'] = pd.factorize(df['FAMI_ESTRATOVIVIENDA_DISCRETO'])[0]

#Discretizar FAMI_TIENEINTERNET
df["FAMI_TIENEINTERNET_DISCRETO"] = df["FAMI_TIENEINTERNET"]
df['FAMI_TIENEINTERNET'] = pd.factorize(df['FAMI_TIENEINTERNET_DISCRETO'])[0]

#Discretizar puntaje global

df["PUNT_GLOBAL_DISCRETO"] = df["PUNT_GLOBAL"]

df.loc[df["PUNT_GLOBAL_DISCRETO"] < 100, "PUNT_GLOBAL" ] = 1
df.loc[(100 <= df["PUNT_GLOBAL_DISCRETO"]) & (df["PUNT_GLOBAL_DISCRETO"] < 200), "PUNT_GLOBAL" ] = 2
df.loc[(200 <= df["PUNT_GLOBAL_DISCRETO"]) & (df["PUNT_GLOBAL_DISCRETO"] < 300), "PUNT_GLOBAL" ] = 3
df.loc[(300 <= df["PUNT_GLOBAL_DISCRETO"]) & (df["PUNT_GLOBAL_DISCRETO"] < 400), "PUNT_GLOBAL" ] = 4
df.loc[(400 <= df["PUNT_GLOBAL_DISCRETO"]) & (df["PUNT_GLOBAL_DISCRETO"] < 500), "PUNT_GLOBAL" ] = 5
df.PUNT_GLOBAL = df.PUNT_GLOBAL.astype(int)
#No lo toma como numero

#Discretizar periodo
df["PERIODO_DISCRETO"] = df["PERIODO"]

df.loc[(df["PERIODO_DISCRETO"] == 20191), "PERIODO"] = 1
df.loc[(df["PERIODO_DISCRETO"] == 20194), "PERIODO"] = 4
df.PERIODO = df.PERIODO.astype(int)

#Eliminamos columnas sobrantes
df.drop(["PERIODO_DISCRETO", "PUNT_GLOBAL_DISCRETO","COLE_AREA_UBICACION_DISCRETO","COLE_BILINGUE_DISCRETO",
         "COLE_DEPTO_UBICACION_DISCRETO","COLE_JORNADA_DISCRETO","COLE_MCPIO_UBICACION_DISCRETO",
         "FAMI_EDUCACIONMADRE_DISCRETO","FAMI_EDUCACIONPADRE_DISCRETO","FAMI_ESTRATOVIVIENDA_DISCRETO","FAMI_TIENEINTERNET_DISCRETO"], axis=1, inplace=True)
df
# Out:
#         PERIODO  COLE_AREA_UBICACION  COLE_BILINGUE  COLE_DEPTO_UBICACION  \
# 0             4                    0              0                     0
# 1             4                    0              0                     1
# 2             4                    0              0                     1
# 3             4                    0              0                     2
# 4             4                    0              0                     2
# ...         ...                  ...            ...                   ...
# 869317        4                    0              0                     9
# 869318        4                    0              0                    19
# 869319        4                    0              0                    19
# 869320        4                    1              0                    17
# 869321        4                    1              0                    17
#
#         COLE_JORNADA  COLE_MCPIO_UBICACION ESTU_GENERO  FAMI_EDUCACIONMADRE  \
# 0                  0                     0           M                    0
# 1                  0                     1           F                    1
# 2                  0                     1           F                    1
# 3                  1                     2           M                    2
# 4                  1                     2           M                    2
# ...              ...                   ...         ...                  ...
# 869317             3                   490           F                    6
# 869318             3                   629           M                    0
# 869319             3                   629           M                    0
# 869320             3                   383           M                    3
# 869321             3                   383           M                    3
#
#         FAMI_EDUCACIONPADRE  FAMI_ESTRATOVIVIENDA  FAMI_TIENEINTERNET  \
# 0                         0                     0                   0
# 1                         1                     0                   0
# 2                         1                     0                   0
# 3                         2                     0                   1
# 4                         2                     0                   1
# ...                     ...                   ...                 ...
# 869317                    9                     1                   0
# 869318                    8                     0                   0
# 869319                    8                     0                   0
# 869320                    9                     1                   0
# 869321                    9                     1                   0
#
#         PUNT_GLOBAL
# 0                 3
# 1                 4
# 2                 4
# 3                 3
# 4                 3
# ...             ...
# 869317            3
# 869318            3
# 869319            3
# 869320            3
# 869321            3
#
# [869322 rows x 12 columns]

# %%
#Creamos modelo
model = BayesianNetwork(
    [ ("FAMI_TIENEINTERNET", "PUNT_GLOBAL"),
     ("COLE_BILINGUE", "PUNT_GLOBAL"),
     ("FAMI_ESTRATOVIVIENDA", "FAMI_TIENEINTERNET"),
     ("PERIODO", "COLE_BILINGUE"),
     ("COLE_JORNADA", "COLE_BILINGUE"),
     ("FAMI_EDUCACIONMADRE", "FAMI_ESTRATOVIVIENDA"),
     ("FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA"),
     ("COLE_MCPIO_UBICACION", "COLE_BILINGUE"),     
     ("COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION"),
     ("COLE_AREA_UBICACION", "COLE_DEPTO_UBICACION"),
     ("COLE_AREA_UBICACION", "FAMI_ESTRATOVIVIENDA"),
     ("FAMI_ESTRATOVIVIENDA", "COLE_BILINGUE"),

    ]
)

# %%
#MAXIMUM LIKELIHOOD
model.fit(
    data=df,
    estimator=MaximumLikelihoodEstimator
)

for i in model.nodes():
    print(i)
    print(model.get_cpds(i))
# Out:
# FAMI_TIENEINTERNET
# +-----------------------+-----+--------------------------+
# | FAMI_ESTRATOVIVIENDA  | ... | FAMI_ESTRATOVIVIENDA(17) |
# +-----------------------+-----+--------------------------+
# | FAMI_TIENEINTERNET(0) | ... | 0.0                      |
# +-----------------------+-----+--------------------------+
# | FAMI_TIENEINTERNET(1) | ... | 1.0                      |
# +-----------------------+-----+--------------------------+
# PUNT_GLOBAL
# +--------------------+-----+-----------------------+
# | COLE_BILINGUE      | ... | COLE_BILINGUE(1)      |
# +--------------------+-----+-----------------------+
# | FAMI_TIENEINTERNET | ... | FAMI_TIENEINTERNET(1) |
# +--------------------+-----+-----------------------+
# | PUNT_GLOBAL(1)     | ... | 0.0                   |
# +--------------------+-----+-----------------------+
# | PUNT_GLOBAL(2)     | ... | 0.08584091439234896   |
# +--------------------+-----+-----------------------+
# | PUNT_GLOBAL(3)     | ... | 0.37030557499416844   |
# +--------------------+-----+-----------------------+
# | PUNT_GLOBAL(4)     | ... | 0.520293911826452     |
# +--------------------+-----+-----------------------+
# | PUNT_GLOBAL(5)     | ... | 0.023559598787030556  |
# +--------------------+-----+-----------------------+
# COLE_BILINGUE
# +----------------------+-----+----------------------------+
# | COLE_JORNADA         | ... | COLE_JORNADA(5)            |
# +----------------------+-----+----------------------------+
# | COLE_MCPIO_UBICACION | ... | COLE_MCPIO_UBICACION(1019) |
# +----------------------+-----+----------------------------+
# | FAMI_ESTRATOVIVIENDA | ... | FAMI_ESTRATOVIVIENDA(17)   |
# +----------------------+-----+----------------------------+
# | PERIODO              | ... | PERIODO(4)                 |
# +----------------------+-----+----------------------------+
# | COLE_BILINGUE(0)     | ... | 0.5                        |
# +----------------------+-----+----------------------------+
# | COLE_BILINGUE(1)     | ... | 0.5                        |
# +----------------------+-----+----------------------------+
# FAMI_ESTRATOVIVIENDA
# +--------------------------+-----+-------------------------+
# | COLE_AREA_UBICACION      | ... | COLE_AREA_UBICACION(1)  |
# +--------------------------+-----+-------------------------+
# | FAMI_EDUCACIONMADRE      | ... | FAMI_EDUCACIONMADRE(17) |
# +--------------------------+-----+-------------------------+
# | FAMI_EDUCACIONPADRE      | ... | FAMI_EDUCACIONPADRE(11) |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(0)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(1)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(2)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(3)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(4)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(5)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(6)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(7)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(8)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(9)  | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(10) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(11) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(12) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(13) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(14) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(15) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(16) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# | FAMI_ESTRATOVIVIENDA(17) | ... | 0.05555555555555555     |
# +--------------------------+-----+-------------------------+
# PERIODO
# +------------+-----------+
# | PERIODO(1) | 0.0122348 |
# +------------+-----------+
# | PERIODO(4) | 0.987765  |
# +------------+-----------+
# COLE_JORNADA
# +-----------------+-----------+
# | COLE_JORNADA(0) | 0.476923  |
# +-----------------+-----------+
# | COLE_JORNADA(1) | 0.0591933 |
# +-----------------+-----------+
# | COLE_JORNADA(2) | 0.125521  |
# +-----------------+-----------+
# | COLE_JORNADA(3) | 0.171615  |
# +-----------------+-----------+
# | COLE_JORNADA(4) | 0.111115  |
# +-----------------+-----------+
# | COLE_JORNADA(5) | 0.0556319 |
# +-----------------+-----------+
# FAMI_EDUCACIONMADRE
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(0)  | 0.146297    |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(1)  | 0.105562    |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(2)  | 0.265445    |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(3)  | 0.0996489   |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(4)  | 0.111475    |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(5)  | 0.148477    |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(6)  | 0.0244869   |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(7)  | 0.0227879   |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(8)  | 0.0179312   |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(9)  | 0.0243051   |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(10) | 0.0313957   |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(11) | 0.00197395  |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(12) | 3.10587e-05 |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(13) | 9.31761e-05 |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(14) | 7.47709e-05 |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(15) | 1.15032e-06 |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(16) | 5.75161e-06 |
# +-------------------------+-------------+
# | FAMI_EDUCACIONMADRE(17) | 9.20257e-06 |
# +-------------------------+-------------+
# FAMI_EDUCACIONPADRE
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(0)  | 0.137753  |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(1)  | 0.094974  |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(2)  | 0.0625131 |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(3)  | 0.0364146 |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(4)  | 0.10176   |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(5)  | 0.0219677 |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(6)  | 0.0214109 |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(7)  | 0.0705377 |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(8)  | 0.189421  |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(9)  | 0.229673  |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(10) | 0.020195  |
# +-------------------------+-----------+
# | FAMI_EDUCACIONPADRE(11) | 0.0133794 |
# +-------------------------+-----------+
# COLE_MCPIO_UBICACION
# +----------------------------+-----+--------------------------+
# | COLE_DEPTO_UBICACION       | ... | COLE_DEPTO_UBICACION(33) |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(0)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(2)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(3)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(4)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(5)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(6)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(7)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(8)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(9)    | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(10)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(11)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(12)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(13)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(14)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(15)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(16)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(17)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(18)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(19)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(20)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(21)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(22)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(23)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(24)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(25)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(26)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(27)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(28)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(29)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(30)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(31)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(32)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(33)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(34)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(35)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(36)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(37)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(38)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(39)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(40)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(41)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(42)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(43)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(44)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(45)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(46)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(47)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(48)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(49)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(50)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(51)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(52)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(53)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(54)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(55)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(56)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(57)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(58)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(59)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(60)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(61)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(62)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(63)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(64)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(65)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(66)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(67)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(68)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(69)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(70)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(71)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(72)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(73)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(74)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(75)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(76)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(77)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(78)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(79)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(80)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(81)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(82)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(83)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(84)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(85)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(86)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(87)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(88)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(89)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(90)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(91)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(92)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(93)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(94)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(95)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(96)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(97)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(98)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(99)   | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(100)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(101)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(102)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(103)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(104)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(105)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(106)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(107)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(108)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(109)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(110)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(111)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(112)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(113)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(114)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(115)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(116)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(117)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(118)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(119)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(120)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(121)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(122)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(123)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(124)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(125)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(126)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(127)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(128)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(129)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(130)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(131)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(132)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(133)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(134)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(135)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(136)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(137)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(138)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(139)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(140)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(141)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(142)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(143)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(144)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(145)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(146)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(147)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(148)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(149)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(150)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(151)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(152)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(153)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(154)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(155)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(156)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(157)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(158)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(159)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(160)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(161)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(162)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(163)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(164)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(165)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(166)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(167)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(168)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(169)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(170)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(171)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(172)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(173)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(174)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(175)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(176)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(177)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(178)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(179)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(180)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(181)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(182)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(183)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(184)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(185)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(186)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(187)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(188)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(189)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(190)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(191)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(192)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(193)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(194)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(195)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(196)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(197)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(198)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(199)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(200)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(201)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(202)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(203)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(204)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(205)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(206)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(207)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(208)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(209)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(210)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(211)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(212)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(213)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(214)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(215)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(216)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(217)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(218)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(219)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(220)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(221)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(222)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(223)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(224)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(225)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(226)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(227)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(228)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(229)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(230)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(231)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(232)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(233)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(234)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(235)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(236)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(237)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(238)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(239)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(240)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(241)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(242)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(243)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(244)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(245)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(246)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(247)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(248)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(249)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(250)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(251)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(252)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(253)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(254)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(255)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(256)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(257)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(258)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(259)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(260)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(261)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(262)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(263)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(264)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(265)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(266)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(267)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(268)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(269)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(270)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(271)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(272)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(273)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(274)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(275)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(276)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(277)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(278)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(279)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(280)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(281)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(282)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(283)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(284)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(285)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(286)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(287)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(288)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(289)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(290)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(291)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(292)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(293)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(294)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(295)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(296)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(297)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(298)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(299)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(300)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(301)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(302)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(303)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(304)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(305)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(306)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(307)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(308)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(309)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(310)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(311)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# ...
# | COLE_MCPIO_UBICACION(941)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(942)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(943)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(944)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(945)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(946)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(947)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(948)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(949)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(950)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(951)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(952)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(953)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(954)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(955)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(956)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(957)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(958)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(959)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(960)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(961)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(962)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(963)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(964)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(965)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(966)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(967)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(968)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(969)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(970)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(971)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(972)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(973)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(974)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(975)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(976)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(977)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(978)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(979)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(980)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(981)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(982)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(983)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(984)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(985)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(986)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(987)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(988)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(989)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(990)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(991)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(992)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(993)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(994)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(995)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(996)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(997)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(998)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(999)  | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1000) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1001) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1002) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1003) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1004) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1005) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1006) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1007) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1008) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1009) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1010) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1011) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1012) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1013) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1014) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1015) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1016) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1017) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1018) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# | COLE_MCPIO_UBICACION(1019) | ... | 0.0                      |
# +----------------------------+-----+--------------------------+
# COLE_DEPTO_UBICACION
# +--------------------------+------------------------+------------------------+
# | COLE_AREA_UBICACION      | COLE_AREA_UBICACION(0) | COLE_AREA_UBICACION(1) |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(0)  | 0.0607660825684428     | 0.0911627825600112     |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(1)  | 0.027167852081429383   | 0.057071873469102107   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(2)  | 0.06438325320194435    | 0.013366925607110365   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(3)  | 0.030929391663686575   | 0.022797256630974875   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(4)  | 0.028158567436192897   | 0.07119112604101056    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(5)  | 0.008442272287784268   | 0.00633354328504444    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(6)  | 0.17306260844227228    | 0.008065644901672615   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(7)  | 0.030378405584032      | 0.03684652529918119    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(8)  | 0.023239427292353745   | 0.027433690251242215   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(9)  | 0.02294804042330565    | 0.033504793897403594   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(10) | 0.1370405689990861     | 0.1350776821331094     |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(11) | 0.08130355889325969    | 0.06875918538736091    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(12) | 0.025929457887974995   | 0.042480229547204144   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(13) | 0.01838651143693461    | 0.053240254741409476   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(14) | 0.041674944702719166   | 0.0619707467282525     |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(15) | 0.014446166275943365   | 0.0187556861921758     |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(16) | 0.04857948901339055    | 0.04492966617677934    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(17) | 0.019252725129468483   | 0.02734621037161453    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(18) | 0.013003801274155308   | 0.008494296311848275   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(19) | 0.033273731473755314   | 0.033697249632584504   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(20) | 0.021790439861723687   | 0.020925187206942402   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(21) | 0.01775075826810241    | 0.029428231506753447   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(22) | 0.0077614866028264526  | 0.009972706277556162   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(23) | 0.01066211043562337    | 0.0122996710756526     |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(24) | 0.0007787976318194461  | 0.0014521660018195816  |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(25) | 0.019382524734771724   | 0.029559451326194974   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(26) | 0.002895325889723315   | 0.0005598712296171881  |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(27) | 0.005957536986265083   | 0.009710266638673104   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(28) | 0.0014516364021668587  | 0.00267688431660718    |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(29) | 0.006460841578257242   | 0.012212191196024914   |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(30) | 0.0010622375862571357  | 0.0025894044369794947  |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(31) | 0.0003072806982688971  | 0.0011547344110854503  |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(32) | 0.0005509860796545741  | 0.0005598712296171881  |
# +--------------------------+------------------------+------------------------+
# | COLE_DEPTO_UBICACION(33) | 0.0008211811764082595  | 0.004373993981384282   |
# +--------------------------+------------------------+------------------------+
# COLE_AREA_UBICACION
# +------------------------+----------+
# | COLE_AREA_UBICACION(0) | 0.868504 |
# +------------------------+----------+
# | COLE_AREA_UBICACION(1) | 0.131496 |
# +------------------------+----------+

# %%
def inference(evidence):
    infer=VariableElimination(model)
    prob=infer.query(variables=['PUNT_GLOBAL'], evidence=evidence)
    return prob.values
print(inference({
        'PERIODO':1,
        'COLE_MCPIO_UBICACION':58}))
# Out:
# [1.11852754e-04 1.78487573e-01 5.50983276e-01 2.62425417e-01
#  7.99188100e-03]

# %%
#Método evaluativo modelo

df.isna().sum()
train_data = df.iloc[:695458] #Partimos que el 80% sean de entrenamiento
test_data =df.iloc[695458:] #Partimos que el 20% restante sean de testeo

model_entrenamiento = BayesianModel(
    [ ("FAMI_TIENEINTERNET", "PUNT_GLOBAL"),
     ("COLE_BILINGUE", "PUNT_GLOBAL"),
     ("FAMI_ESTRATOVIVIENDA", "FAMI_TIENEINTERNET"),
     ("PERIODO", "COLE_BILINGUE"),
     ("COLE_JORNADA", "COLE_BILINGUE"),
     ("FAMI_EDUCACIONMADRE", "FAMI_ESTRATOVIVIENDA"),
     ("FAMI_EDUCACIONPADRE", "FAMI_ESTRATOVIVIENDA"),
     ("COLE_MCPIO_UBICACION", "COLE_BILINGUE"),     
     ("COLE_DEPTO_UBICACION", "COLE_MCPIO_UBICACION"),
     ("COLE_AREA_UBICACION", "COLE_DEPTO_UBICACION"),
     ("COLE_AREA_UBICACION", "FAMI_ESTRATOVIVIENDA"),
     ("FAMI_ESTRATOVIVIENDA", "COLE_BILINGUE"),

    ]
)

model_entrenamiento.fit(train_data, estimator=MaximumLikelihoodEstimator)

# Creamos VariableElimination para los 2 modelos
y_pred_test = []
infer_train = VariableElimination(model_entrenamiento)


for i in range(len(test_data)):
    queryt = infer_train.query(variables=['PUNT_GLOBAL'], evidence={'PERIODO': test_data.iloc[i,0], 'COLE_AREA_UBICACION': test_data.iloc[i,1],'COLE_BILINGUE': test_data.iloc[i,2],'COLE_DEPTO_UBICACION': test_data.iloc[i,3],
                                                                    'COLE_JORNADA': test_data.iloc[i,4],'COLE_MCPIO_UBICACION': test_data.iloc[i,5],'FAMI_EDUCACIONMADRE': test_data.iloc[i,7], 'FAMI_EDUCACIONPADRE': test_data.iloc[i,8],
                                                                     'FAMI_EDUCACIONPADRE': test_data.iloc[i,8], 'FAMI_ESTRATOVIVIENDA': test_data.iloc[i,9], 'FAMI_TIENEINTERNET': test_data.iloc[i,10] })   
    prob2 = queryt.values
    
    
    if prob2[1]>=0.5:

        y_pred_test.append(1)
    else:
        y_pred_test.append(0)  # 1 es el índice de la etiqueta positiva
# Out:
# C:\Users\natty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# C:\Users\natty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pgmpy\models\BayesianModel.py:8: FutureWarning: BayesianModel has been renamed to BayesianNetwork. Please use BayesianNetwork class, BayesianModel will be removed in future.
#   warnings.warn(
# C:\Users\natty\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pgmpy\factors\discrete\DiscreteFactor.py:478: RuntimeWarning: invalid value encountered in divide
#   phi.values = phi.values / phi.values.sum()
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 32
#      28 infer_train = VariableElimination(model_entrenamiento)
#      31 for i in range(len(test_data)):
# ---> 32     queryt = infer_train.query(variables=['PUNT_GLOBAL'], evidence={'PERIODO': test_data.iloc[i,0], 'COLE_AREA_UBICACION': test_data.iloc[i,1],'COLE_BILINGUE': test_data.iloc[i,2],'COLE_DEPTO_UBICACION': test_data.iloc[i,3],
#      33                                                                     'COLE_JORNADA': test_data.iloc[i,4],'COLE_MCPIO_UBICACION': test_data.iloc[i,5],'FAMI_EDUCACIONMADRE': test_data.iloc[i,7], 'FAMI_EDUCACIONPADRE': test_data.iloc[i,8],
#      34                                                                      'FAMI_EDUCACIONPADRE': test_data.iloc[i,8], 'FAMI_ESTRATOVIVIENDA': test_data.iloc[i,9], 'FAMI_TIENEINTERNET': test_data.iloc[i,10] })
#      35     prob2 = queryt.values
#      38     if prob2[1]>=0.5:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pgmpy\inference\ExactInference.py:337, in VariableElimination.query(self, variables, evidence, virtual_evidence, elimination_order, joint, show_progress)
#     335 indexer = [slice(None)] * len(phi.variables)
#     336 for index in indexes_to_reduce:
# --> 337     indexer[index] = phi.get_state_no(
#     338         phi.variables[index], evidence[phi.variables[index]]
#     339     )
#     340 reduce_indexes.append(tuple(indexer))
#     341 reshape_indexes.append(
#     342     [
#     343         1 if indexer != slice(None) else phi.cardinality[i]
#     344         for i, indexer in enumerate(reduce_indexes[-1])
#     345     ]
#     346 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pgmpy\utils\state_name.py:72, in StateNameMixin.get_state_no(self, var, state_name)
#      68 """
#      69 Given `var` and `state_name` return the state number.
#      70 """
#      71 if self.state_names:
# ---> 72     return self.name_to_no[var][state_name]
#      73 else:
#      74     return state_name
#
# KeyError: 17
